# %%
pip install pandas-datareader
# Out:
# ...
#      -------------------------------------- 109.5/109.5 kB 6.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web
from datetime import datetime

start_date = datetime(2006, 1, 1)
end_date = datetime(2016, 1, 1)
# Data is imported from stooq
bac = web.DataReader('BAC', 'stooq', start_date, end_date)
bac.head()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2015-12-31  14.7814  14.8325  14.6233  14.6233  5.417059e+07
# 2015-12-30  14.9473  14.9807  14.8070  14.8168  4.030734e+07
# 2015-12-29  14.9897  15.0780  14.9130  15.0131  5.251059e+07
# 2015-12-28  14.9630  14.9720  14.7539  14.8846  4.803435e+07
# 2015-12-24  15.0495  15.1035  14.9630  15.0063  3.380344e+07

# %%
import pandas_datareader.data as web
from datetime import datetime

start_date = datetime(2020, 1, 1)
end_date = datetime(2023, 10, 9)


data= web.DataReader(['AAPL', 'GOOG', 'TSLA'], 'stooq', start_date, end_date)
data.head()
# Out:
# Attributes   Close                    High                       Low           \
# Symbols       AAPL    GOOG    TSLA    AAPL      GOOG    TSLA    AAPL     GOOG
# Date
# 2023-10-09  178.99  139.50  259.67  179.05  139.9700  261.36  175.80  136.700
# 2023-10-06  177.49  138.73  260.53  177.99  139.1857  261.65  173.18  134.940
# 2023-10-05  174.91  135.99  260.05  175.45  136.5000  263.60  172.68  134.455
# 2023-10-04  173.66  136.27  261.16  174.21  136.5700  261.86  170.97  133.430
# 2023-10-03  172.40  133.30  246.53  173.63  135.2400  250.02  170.82  132.815
#
# Attributes             Open                      Volume              \
# Symbols       TSLA     AAPL    GOOG    TSLA        AAPL        GOOG
# Date
# 2023-10-09  252.05  176.810  137.99  255.31  42390772.0  16599099.0
# 2023-10-06  250.65  173.800  134.94  253.98  57266675.0  20826683.0
# 2023-10-05  256.25  173.790  136.13  260.00  48527918.0  15922944.0
# ...

# %%
import pandas_datareader.data as web
from datetime import datetime, timedelta
import matplotlib.pyplot as plt



#  Checking for MultiIndex
if isinstance(data.index, pd.MultiIndex):
    print("MultiIndex is being used.")
else:
    print("No MultiIndex is being used.")

# Plotting the Closing Price of AAPL
plt.figure(figsize=(12, 6))



data['Close']['AAPL'].plot()



plt.title("Closing Price of AAPL")
plt.xlabel("Date")


plt.ylabel("Price ")

plt.grid(True)

plt.show()
# Out:
# No MultiIndex is being used.

# %%
# Printing the Closing Price of All Three Stocks Yesterday
# No of days is mentioned as 5 since data is available for those days only
yesterday = datetime.now() - timedelta(days=5)


yesterday_data = data.loc[yesterday.strftime('%Y-%m-%d')]


print("Closing Price of AAPL ", yesterday_data['Close']['AAPL'])


print("Closing Price of GOOG ", yesterday_data['Close']['GOOG'])



print("Closing Price of TSLA ", yesterday_data['Close']['TSLA'])


 
tsla_data = data.xs('TSLA', axis=1, level='Symbols')
# Out:
# Closing Price of AAPL yesterday: 174.91
# Closing Price of GOOG yesterday: 135.99
# Closing Price of TSLA yesterday: 260.05
