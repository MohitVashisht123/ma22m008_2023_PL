# %%
# SVD
from scipy.linalg import svd
import numpy as np
np.set_printoptions(precision=3, suppress=True)

# %%
a = np.random.rand(4, 5) + 1j * np.random.rand(4, 5)
u, s, vh = svd(a)

# %%
a = np.random.rand(4, 5) + 1j * np.random.rand(4, 5)
u, s, vh = svd(a)

# %%
a = np.random.rand(4, 5) + 1j * np.random.rand(4, 5)
u, s, vh = svd(a)

# %%
# outer product
# 1 method
u[0,:,np.newaxis]@ vh[np.newaxis,0,:]
# 2 method
np.outer(u[0,:],vh[0,:])
# Out:
# array([[0.146+0.174j, 0.126+0.151j, 0.203+0.134j, 0.171+0.123j,
#         0.103+0.102j],
#        [0.071+0.085j, 0.062+0.074j, 0.099+0.066j, 0.083+0.06j ,
#         0.05 +0.05j ],
#        [0.23 +0.275j, 0.2  +0.239j, 0.321+0.212j, 0.27 +0.194j,
#         0.163+0.161j],
#        [0.139+0.166j, 0.121+0.145j, 0.194+0.129j, 0.164+0.117j,
#         0.099+0.098j]])

# %%
ar=np.zeros_like(a)
for i in range(4):
    ar+=np.outer(u[:,i],s[i]*vh[i,:])

# %%
a-ar
# Out:
# array([[-0.-0.j,  0.+0.j,  0.-0.j,  0.+0.j,  0.-0.j],
#        [-0.-0.j,  0.-0.j,  0.-0.j, -0.+0.j, -0.-0.j],
#        [ 0.-0.j,  0.-0.j, -0.+0.j,  0.+0.j, -0.+0.j],
#        [ 0.+0.j,  0.-0.j, -0.-0.j, -0.+0.j, -0.-0.j]])

# %%
# Geometry of SVD
import matplotlib.pyplot as plt
# %matplotlib inline
def show(c):
    plt.plot(c[0, :], c[1, :])
    plt.axis('image');

# %%
t = np.linspace(0, 3.5 * np.pi , num=300)
l = np.linspace(-1, 1, num=10)
z = np.zeros_like(l)
c = np.array([np.concatenate([l, np.cos(t), z]),
            np.concatenate([z, np.sin(t), l])])
show(c)

# %%
a1=a.reshape(10,2)
t = np.linspace(0, 3.5 * np.pi , num=300)
l = np.linspace(-1, 1, num=10)
z = np.zeros_like(l)
c = np.array([np.concatenate([l, np.cos(t), z]),
            np.concatenate([z, np.sin(t), l])])
c.reshape(2,320)
show(a1 @ c)
# Out:
# C:\Users\mvash\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
print(a.shape)
# Out:
# (4, 5)

# %%
vh.shape

# c1=c.reshape(5,128)
show(vh @ c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9336\1578251000.py in <module>
#       2
#       3 # c1=c.reshape(5,128)
# ----> 4 show(vh @ c)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 5)

# %% [markdown]
# # Error tolerance in svd
# (σ2 · + σ2)1/2 ≤ ε.

# %% [markdown]
# As you can see, the low rank approximation does give some image compression. The
# number of entries needed to store a rank ℓ approximation cl of an m × n matrix is mℓ +
# ℓ + ℓn:
# [29]: u.shape[0] * l + l + l * vh.shape[0]
