# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from celluloid import Camera

# %%
pip install celluloid
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Function definition
def f(x, t):
    return 0.5 * (x + t)**2 + 2 * np.sin(10 * (x - t))

# %%
# Task 1
fig, ax = plt.subplots()
x = np.linspace(0, 10, 1000)
line, = ax.plot(x, f(x, 0))


def update(t):
    ax.clear() 
    ax.plot(x, f(x, t))  
    ax.set_xlabel('x')
    ax.set_ylabel('f(x, t)')
    ax.set_title(f'f(x, t) at t = {t:.2f}')

# Creating an animation
ani = FuncAnimation(fig, update, frames=np.linspace(0, 10, 200), repeat=False)
# Show the animation
plt.show()

# %%
# Task 2
fig, ax = plt.subplots()
camera = Camera(fig)
x = np.linspace(0, 20, 1000)
# Iterating over time values
for t in np.linspace(0, 20, 200):
    ax.plot(x, f(x, t))
    ax.set_xlabel('x')
    ax.set_ylabel('f(x, t)')
    ax.set_title(f'f(x, t) at t = {t:.2f}')
    camera.snap()
# animation
animation = camera.animate()


plt.show()
# Out:
# C:\Users\mvash\anaconda3\lib\site-packages\matplotlib\animation.py:887: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %% [markdown]
# .

# %%
# Task 3: Add a text labeling the time at each snapshot that the animation is composed of


fig, ax = plt.subplots()
camera = Camera(fig)
x = np.linspace(0, 20, 1000)
for t in np.linspace(0, 20, 200):
    ax.plot(x, f(x, t))
    ax.set_xlabel('x')
    ax.set_ylabel('f(x, t)')
    ax.set_title(f'f(x, t) at t = {t:.2f}')


    ax.text(8, 8, f'Time: {t:.2f}', fontsize=12, color='red')

    camera.snap()

animation = camera.animate()

plt.show()
